# %% [markdown]
# <a href="https://colab.research.google.com/github/AvokrichA/29092022/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание 1 . Выберите любой продукт.
# Например ваш продукт
# ozon.ru
# citilink.ru
# telegram
#
# Какие бы ключевые метрики вы выделили? Опишите почему вы выбрали именно их и можно ли их измерить
#
#
# # **Решение:**
# На примере ozon.ru
# Ключевые метрики:
# 1. ROMI , показывает доходность и окупаемость затрат на маркетинг
# 2. CPA, показывает стоимость целевого действия
# 3. CPL, показывает стоимость лида
# 4. САС, стоимость привлечения клиента
# 5. AOV, метрика, показывающая среднюю сумму заказа
# 6. AR, показывает долю брошенных корзин
# 7. SOM, показывает положение компании на рынке относительно конкурентов.

# %% [markdown]
# # Задание 2. Сформулируйте 5-10 гипотез для выбранного продукта.
#
# 1. Увеличение рекламного бюджета в период предновогодних праздников на 50% снизит CPA на 30%, потому что количество заказов увеличится в 5 раз
# 2. Если указывать основной ценой, цену без ozon карты, то количество заказов увеличится на 15%, потому что эта надпись "Цена по OZON карте" не нравится тем, у кого ее нет.
# 3. Если сделать накопительную систему скидок по озон карте, то количетсво пользователей Ozon карты увеличится на 25%, потому что людям нравятся доп.скидки.
# 4. Если изменить цвета банера на главной странице, на зеленые и синие, то переходы по банеру увеличатся на 40%, потому что люди устали от слишком ярких цветов.
# 5. Если делать рассылку пользователям, которые бросили корзины, с напоминанием, что в корзине лежат товары, это увеличит продажи на 15%, потому что некоторые люди могут отвлечься на другие хлопоты и забыть, что хотели оформить заказ.
#
# 6. Если делать рассылку пользователям, которые бросили корзины, с предложением дополнительной скидки, это увеличит продажи на 10%, потому что некоторые люди, могут уйти на другие ресурцы, в поиске более выгодной цены.
